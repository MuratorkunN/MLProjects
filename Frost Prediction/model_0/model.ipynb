# %%
import pandas as pd
import psycopg2
import numpy as np

# %%
conn = psycopg2.connect(
    host="localhost",
    port="5432",
    dbname="weather_data",
    user="postgres",
    password="frost"
)
