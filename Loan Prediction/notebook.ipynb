# %%
import pandas as pd
import numpy as np
from calendar import monthrange
import matplotlib.pyplot as plt

# %%
df_all = pd.read_csv('accepted_2007_to_2017.csv')

# print(df.head())
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_20152\1933071522.py:1: DtypeWarning: Columns (0,18,48,58,117,128,129,130,133,134,135,138,144,145,146) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_all = pd.read_csv('accepted_2007_to_2017.csv')

# %%
df_all.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=150)

# %%
df_all.shape
# Out:
# (1646801, 150)

# %%
for c in df_all.columns:
    print(c)
# Out:
# id
# member_id
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# desc
# purpose
# title
# zip_code
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# application_type
# annual_inc_joint
# dti_joint
# verification_status_joint
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_act_il
# ...

# %%
df_all[["id"]].drop_duplicates().shape
# Out:
# (1646801, 1)

# %%
df_all["loan_status"].value_counts(dropna = False)
# Out:
# loan_status
# Current                                                788950
# Fully Paid                                             646902
# Charged Off                                            168084
# Late (31-120 days)                                      23763
# In Grace Period                                         10474
# Late (16-30 days)                                        5786
# Does not meet the credit policy. Status:Fully Paid       1988
# Does not meet the credit policy. Status:Charged Off       761
# Default                                                    70
# NaN                                                        23
# Name: count, dtype: int64

# %%
df = df_all[df_all["loan_status"].isin(["Fully Paid", "Charged Off"])].copy()
df.shape
# Out:
# (814986, 150)
